# %% [markdown]
# <a href="https://colab.research.google.com/github/Jamesunekwuojo/forest-sentinel/blob/main/00_setup.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Cell 1: Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Cell 2: Set your project root — change this to match your Drive path
import os
PROJECT_ROOT = '/content/drive/MyDrive/ForestSentinel'
os.chdir(PROJECT_ROOT)
print(f"Working directory: {os.getcwd()}")
# Out:
# Working directory: /content/drive/MyDrive/ForestSentinel

# %%
# Cell 3: Create all necessary folders if they don't exist
folders = [
    'data/raw',
    'data/patches/normal',
    'data/patches/anomaly',
    'checkpoints',
    'model',
    'preprocessing',
    'visualization',
    'outputs'
]
for folder in folders:
    os.makedirs(folder, exist_ok=True)
    print(f"✅ {folder}")
# Out:
# ✅ data/raw
# ✅ data/patches/normal
# ✅ data/patches/anomaly
# ✅ checkpoints
# ✅ model
# ✅ preprocessing
# ✅ visualization
# ✅ outputs

# %%
# Cell 4: Install all required libraries
# This runs every session since Colab resets installations
# !pip install -q transformers torch torchvision
# !pip install -q rasterio earthengine-api
# !pip install -q grad-cam scikit-learn matplotlib opencv-python-headless
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 80.0 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...

# %%
# Cell 5: Verify GPU is available
import torch
print(f"GPU available: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"GPU: {torch.cuda.get_device_name(0)}")
else:
    print("⚠️ No GPU — go to Runtime → Change runtime type → GPU")
# Out:
# GPU available: True
# GPU: Tesla T4
